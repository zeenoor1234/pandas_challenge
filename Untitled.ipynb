# %%
##Load Necessary Libraries

# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd

# %%
gas = pd.read_csv('gas_prices.csv')

plt.figure(figsize=(8,5))

plt.title('Gas Prices Over Time in (in USD)', fontdict= {'fontweight':'bold', 'fontsize': 18})

plt.plot(gas.Year,gas.USA,'b.-', label = 'USA')
plt.plot(gas.Year,gas.Canada,'y.-', label = 'Canada')
plt.plot(gas.Year,gas.Italy, 'g.-', label = 'Italy')
plt.plot(gas.Year,gas.Australia, 'r.-', label = 'Australia')




plt.xticks(gas.Year[::3].tolist()+[2011])

plt.xlabel('Year')
plt.ylabel('US Dollars')

plt.legend()

plt.savefig('Gas_price_figure.png', dpi =300)

plt.show()
